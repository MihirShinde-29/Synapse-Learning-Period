# %% [markdown]
# # Class Models, Custom Layers, GPU training and Custom Resnets

# %% [markdown]
# ## Instructions
# 1. Use Google Collab for this task
# 2. change runtime type to GPU in the Runtime tab

# %% [markdown]
# ## Making models using class
#
# 1. In earlier tasks, we learnt how to make a model using the sequential api provided by tensorflow.
# 2. Now we learnt how to make a model using a class based approach.

# %% [markdown]
# 1. <b>Import</b>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import Sequential, layers, initializers, models, callbacks, optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 2. <b>To avoid GPU errors</b>

# %%
physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# 3. <b>Loading MNIST Data</b>

# %%
(x_train, y_train) , (x_test, y_test) = mnist.load_data()
#flattening the images into 1 dimensional array
x_train = x_train.reshape(-1, 28*28).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28*28).astype("float32") / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
len(x_train)
# Out:
# 60000

# %%
len(x_test)
# Out:
# 10000

# %% [markdown]
# 4. <b>Building the model</b>

# %%
#we will extend the class from keras.Model
#this means that we can use the functionalities of keras.model
#extending a class is an object oriented concept, so google that if you are confused
class MyModel(keras.Model):

  def __init__(self):
    super(MyModel, self).__init__() #super is also an object oriented thing which allows us to call the init method of the parent class (keras.Model here)
    self.dense1 = layers.Dense(64) #self links the variable to the class. You can access dense1 anywhere in this class by using self.dense1
    self.dense2 = layers.Dense(10)

  def call(self, input_tensor):
    x = tf.nn.relu(self.dense1(input_tensor))
    x = self.dense2(x)
    return x

# %% [markdown]
# 5. <b>Creating the model object</b>

# %%
model = MyModel()

# %% [markdown]
# 6. <b>Compiling the model</b>

# %%
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy'],
)

# %% [markdown]
# 7. <b>Fitting the model

# %%
model.fit(x_train, y_train, batch_size=32, epochs=2)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3003 - accuracy: 0.9157
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1457 - accuracy: 0.9580

# %% [markdown]
# 6. <b>Evaluate the model</b>

# %%
model.evaluate(x_test, y_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1258 - accuracy: 0.9623
# [0.12577548623085022, 0.9623000025749207]

# %% [markdown]
# <b>Why class based</b>
# 1. allows for better code visualization
# 2. better connectivity
# 3. helps in modularizing the code

# %% [markdown]
# <b>Now we'll learn to make the layers (like Dense) using classes</b><br><br>
# <b>Why do we need to dive till making layers?</b>
# 1. sometimes when we make our own models, we want to do our operations.<br><br>
#   a. dense follows the operation WX+b<br><br>
#   b. while back propogation, tf uses it's own automatic derivative algorithm to calculate the derivative of this operation and uses it for gradient descent.<br><br>
#   c. What if we want to implement a dense operation which does (WX x 5) + (7 x b)? How will tensorflow account for this derivative?<br><br>
#   d. The answer is : by using the keras.Layer class to build the layer <br><br>
#
# 2. Hence, we can do any complex operation using the Layer class and tensorflow will account for its derivative during back propogation.

# %% [markdown]
# ## Making layers using classes

# %% [markdown]
# 1. <b>Building the Dense layer from scratch</b>

# %%
class MyDense(layers.Layer):
  #when object created, first init is called
  def __init__(self, units=32):
      super(MyDense, self).__init__()
      self.units = units

  #init automatically calls build and the weights are set. init passes the input shape to build automatically. (input shape for dense 1 will be (batch_size, 784) 28*28=784, for dense 2 -> (batch_size,64))
  def build(self, input_shape):
      print(input_shape)
      self.w = self.add_weight(shape=(input_shape[-1], self.units), #why do we choose this shape? ponder (make a neural net diagram and see what shape fits the matrix multiplication W*X)
                               initializer='random_normal', #what other initialization methods exist?
                               trainable=True)
      self.b = self.add_weight(shape=(self.units,),
                               initializer='zeros',
                               trainable=True)

  #build calls the call function which executes the operation
  def call(self, inputs):
      return tf.matmul(inputs, self.w) + self.b

# %% [markdown]
# 2. <b>Using custom Dense to build MyModel</b>

# %%
#we will extend the class from keras.Model
#this means that we can use the functionalities of keras.model
#extending a class is an object oriented concept, so google that if you are confused
class MyModel(keras.Model):

  def __init__(self):
    super(MyModel, self).__init__() #super is also an object oriented thing which allows us to call the init method of the parent class (keras.Model here)
    self.dense1 = MyDense(64) #self links the variable to the class. You can access dense1 anywhere in this class by using self.dense1
    self.dense2 = MyDense(10)

  def call(self, input_tensor):
    x = tf.nn.relu(self.dense1(input_tensor))
    x = self.dense2(x)
    return x

# %% [markdown]
# 3. <b>Training the model </b>

# %%
#train the model
#write code here
model = MyModel()
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy'],
)
model.fit(x_train, y_train, batch_size=32, epochs=2)
# Out:
# Epoch 1/2
# (32, 784)
# (32, 64)
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3382 - accuracy: 0.9087
# Epoch 2/2
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1534 - accuracy: 0.9550

# %% [markdown]
# 4. <b>Testing the model </b>

# %%
#evaluate the model
#write code here
model.evaluate(x_test, y_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1292 - accuracy: 0.9609
# [0.1291770190000534, 0.9609000086784363]

# %% [markdown]
# #### We got a very similar result with our own Dense Layer

# %% [markdown]
# ## Now your turn
# 1. We will build a mini custom version of ResNet CNN architecture using the keras.Model
#
# 2. Resnet solves the problem of vanishing gradients (https://www.youtube.com/watch?v=JIWXbzRXk1I) and allows us to build very deep neural networks.
#
#
# RESNET BLOG RESOURCE : https://towardsdatascience.com/understanding-and-visualizing-resnets-442284831be8
#
# RESNET VIDEO RESOURCE : https://www.youtube.com/watch?v=sAzL4XMke80&t=314s
#
# Read the above blog carefully and watch the video for better understanding as well.

# %% [markdown]
# #### <b>Our Custom Model architecture</b>
# DATASET -> MNIST
#
# 1. Input -> 28,28,1 images
# 2. 8 filters of 5x5, padding none => (24,24,8)
# 3. Resblock 1
#   - 16 filters of 7x7, padding none => (18,18,16) <b>[im_res_1]</b>
#   - 16 filters of 8x8, padding same => (18,18,16)
#   - 16 filters of 10x10, padding same => (18,18,16) <b>[output_res_1]</b>
#   - (sum of output_res_1 and im_res_1 here) => (18,18,16)
# 4. maxpooling => (9,9,16)
# 5. Resblock 2
#   - 32 filters of 6x6, padding none => (4,4,32) <b>[im_res_2]</b>
#   - 32 filters of 7x7, padding same => (4,4,32)
#   - 32 filters of 8x8, padding same => (4,4,32) <b>[output_res_2]</b>
#   - (sum of output_res_2 and im_res_2 here) => (4,4,32)
# 6. maxpooling => (2, 2, 32)
# 7. Flatten => (128,1)
# 8. Dense, 64 units => (64,1)
# 9. Dense, 10 units => (10, 1)
# 10. use softmax to predict

# %% [markdown]
# ### <b>Instructions</b>
# 1. Build the custom Resnet model based on the architecture described above
# 2. Only use class based approach
# 3. Create a custom model using class based approach. Name the Class CustomResNet
# 4. Use RELU as activation function, Batch normalization after every layer
# 5. reload the data as it was already flattened before
# 6. Use custom layers only if you find the use case for it here
#
# ### <b>Notes</b>
# 1. all layers are supposed to be defined in the init method.If defined anyehere else, will result in errors.
# 2. Repititive layers will need seperate initializations
# 3. you can check if your model is correct by the following code : -
#  - model = CustomResNet()
#  - model.build((None,28,28,1))
#  - model.summary()
# 4. Summary must have all layers defined and the trainable paramaetrs should not be zero

# %%
#imports that you can use
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, BatchNormalization, Activation, Add, Input, MaxPool2D
tf.config.run_functions_eagerly(True)

# %%
# load the mnist dataset here
# make sure to resize the dataset to consider the 3rd image dimension as well
# dataset shape must be (num_images, height, width, channel)
# divide data into train and test
# write code here
(x_train, y_train) , (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0

# %%
#make a class based model for Custom ResNet (refer instructions and notes above)
# write code here
class CustomResNet(keras.Model):
  def __init__(self):
    super(CustomResNet, self).__init__()
    self.bn1 = BatchNormalization()
    self.bn2= BatchNormalization()
    self.bn3 = BatchNormalization()
    self.bn4 = BatchNormalization()
    self.bn5 = BatchNormalization()
    self.bn6 = BatchNormalization()
    self.bn7 = BatchNormalization()
    self.mp = MaxPool2D(pool_size=(2, 2), strides=(1, 1), padding='valid')
    self.flat = Flatten()
    self.conv2D1 = Conv2D(filters=8, kernel_size=(5, 5), padding='valid', activation='relu', input_shape=(28, 28, 1))
    self.conv2D2 = Conv2D(filters=16, kernel_size=(7, 7), padding='valid', activation='relu')
    self.conv2D3 = Conv2D(filters=16, kernel_size=(8, 8), padding='same', activation='relu')
    self.conv2D4 = Conv2D(filters=16, kernel_size=(10, 10), padding='same', activation='relu')
    self.conv2D5 = Conv2D(filters=32, kernel_size=(6, 6), padding='valid', activation='relu')
    self.conv2D6 = Conv2D(filters=32, kernel_size=(7, 7), padding='same', activation='relu')
    self.conv2D7 = Conv2D(filters=32, kernel_size=(8, 8), padding='same', activation='relu')
    self.dense1 = Dense(64, activation='relu')
    self.dense2 = Dense(10, activation='softmax')

  def call(self, input_tensor):
    conv1 = self.conv2D1(input_tensor)
    b1 = self.bn1(conv1)
    conv2 = self.conv2D2(b1)
    b2 = self.bn2(conv2)
    conv3 = self.conv2D3(b2)
    b3 = self.bn3(conv3)
    conv4 = self.conv2D4(b3)
    b4 = self.bn4(conv4)
    sum1 = conv2 + conv4
    m1 = self.mp(sum1)
    conv5 = self.conv2D5(m1)
    b5 = self.bn5(conv5)
    conv6 = self.conv2D6(b5)
    b6 = self.bn6(conv6)
    conv7 = self.conv2D7(b6)
    b7 = self.bn7(conv4)
    sum2 = conv5 + conv7
    m2 = self.mp(sum2)
    flat = self.flat(m2)
    d1 = self.dense1(flat)
    d2 = self.dense2(d1)
    return d2

# %%
#find summary of model
# write code here
model = CustomResNet()
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy'],
)

# %%
#train model here
model.fit(x_train, y_train, batch_size=32, epochs=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    1/1875 [..............................] - ETA: 1:46 - loss: 0.0957 - accuracy: 0.9375WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    2/1875 [..............................] - ETA: 1:39 - loss: 0.0876 - accuracy: 0.9531WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    3/1875 [..............................] - ETA: 1:39 - loss: 0.0631 - accuracy: 0.9688WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    4/1875 [..............................] - ETA: 1:38 - loss: 0.0805 - accuracy: 0.9531WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    5/1875 [..............................] - ETA: 1:41 - loss: 0.0665 - accuracy: 0.9625WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    6/1875 [..............................] - ETA: 1:42 - loss: 0.0557 - accuracy: 0.9688WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    7/1875 [..............................] - ETA: 1:42 - loss: 0.0511 - accuracy: 0.9732WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    8/1875 [..............................] - ETA: 1:42 - loss: 0.0452 - accuracy: 0.9766WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#    9/1875 [..............................] - ETA: 1:41 - loss: 0.0403 - accuracy: 0.9792WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   10/1875 [..............................] - ETA: 1:41 - loss: 0.0687 - accuracy: 0.9781WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   11/1875 [..............................] - ETA: 1:40 - loss: 0.0634 - accuracy: 0.9801WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   12/1875 [..............................] - ETA: 1:40 - loss: 0.0617 - accuracy: 0.9818WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   13/1875 [..............................] - ETA: 1:41 - loss: 0.0573 - accuracy: 0.9832WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   14/1875 [..............................] - ETA: 1:40 - loss: 0.0644 - accuracy: 0.9821WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   15/1875 [..............................] - ETA: 1:40 - loss: 0.0632 - accuracy: 0.9812WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   16/1875 [..............................] - ETA: 1:40 - loss: 0.0618 - accuracy: 0.9805WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   17/1875 [..............................] - ETA: 1:40 - loss: 0.0654 - accuracy: 0.9798WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   18/1875 [..............................] - ETA: 1:40 - loss: 0.0627 - accuracy: 0.9809WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   19/1875 [..............................] - ETA: 1:40 - loss: 0.0643 - accuracy: 0.9803WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   20/1875 [..............................] - ETA: 1:40 - loss: 0.0624 - accuracy: 0.9812WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   21/1875 [..............................] - ETA: 1:39 - loss: 0.0615 - accuracy: 0.9821WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   22/1875 [..............................] - ETA: 1:40 - loss: 0.0593 - accuracy: 0.9830WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   23/1875 [..............................] - ETA: 1:40 - loss: 0.0664 - accuracy: 0.9823WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   24/1875 [..............................] - ETA: 1:40 - loss: 0.0671 - accuracy: 0.9818WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   25/1875 [..............................] - ETA: 1:40 - loss: 0.0649 - accuracy: 0.9825WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   26/1875 [..............................] - ETA: 1:39 - loss: 0.0761 - accuracy: 0.9808WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   27/1875 [..............................] - ETA: 1:39 - loss: 0.0733 - accuracy: 0.9815WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   28/1875 [..............................] - ETA: 1:39 - loss: 0.0758 - accuracy: 0.9799WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   29/1875 [..............................] - ETA: 1:40 - loss: 0.0734 - accuracy: 0.9806WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   30/1875 [..............................] - ETA: 1:39 - loss: 0.0715 - accuracy: 0.9812WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   31/1875 [..............................] - ETA: 1:40 - loss: 0.0713 - accuracy: 0.9808WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   32/1875 [..............................] - ETA: 1:40 - loss: 0.0692 - accuracy: 0.9814WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   33/1875 [..............................] - ETA: 1:40 - loss: 0.0672 - accuracy: 0.9820WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   34/1875 [..............................] - ETA: 1:40 - loss: 0.0654 - accuracy: 0.9825WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   35/1875 [..............................] - ETA: 1:40 - loss: 0.0637 - accuracy: 0.9830WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   36/1875 [..............................] - ETA: 1:40 - loss: 0.0655 - accuracy: 0.9826WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   37/1875 [..............................] - ETA: 1:40 - loss: 0.0646 - accuracy: 0.9831WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   38/1875 [..............................] - ETA: 1:40 - loss: 0.0638 - accuracy: 0.9836WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   39/1875 [..............................] - ETA: 1:40 - loss: 0.0642 - accuracy: 0.9832WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   40/1875 [..............................] - ETA: 1:39 - loss: 0.0629 - accuracy: 0.9836WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   41/1875 [..............................] - ETA: 1:39 - loss: 0.0616 - accuracy: 0.9840WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   42/1875 [..............................] - ETA: 1:39 - loss: 0.0614 - accuracy: 0.9836WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   43/1875 [..............................] - ETA: 1:40 - loss: 0.0602 - accuracy: 0.9840WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   44/1875 [..............................] - ETA: 1:40 - loss: 0.0615 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   45/1875 [..............................] - ETA: 1:40 - loss: 0.0610 - accuracy: 0.9840WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   46/1875 [..............................] - ETA: 1:40 - loss: 0.0597 - accuracy: 0.9844WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   47/1875 [..............................] - ETA: 1:40 - loss: 0.0604 - accuracy: 0.9834WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   48/1875 [..............................] - ETA: 1:40 - loss: 0.0595 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   49/1875 [..............................] - ETA: 1:40 - loss: 0.0586 - accuracy: 0.9841WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   50/1875 [..............................] - ETA: 1:40 - loss: 0.0613 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   51/1875 [..............................] - ETA: 1:40 - loss: 0.0654 - accuracy: 0.9822WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   52/1875 [..............................] - ETA: 1:40 - loss: 0.0670 - accuracy: 0.9820WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   53/1875 [..............................] - ETA: 1:40 - loss: 0.0673 - accuracy: 0.9817WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   54/1875 [..............................] - ETA: 1:40 - loss: 0.0662 - accuracy: 0.9821WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   55/1875 [..............................] - ETA: 1:40 - loss: 0.0666 - accuracy: 0.9812WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   56/1875 [..............................] - ETA: 1:40 - loss: 0.0655 - accuracy: 0.9816WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   57/1875 [..............................] - ETA: 1:40 - loss: 0.0646 - accuracy: 0.9819WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   58/1875 [..............................] - ETA: 1:40 - loss: 0.0666 - accuracy: 0.9817WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   59/1875 [..............................] - ETA: 1:40 - loss: 0.0655 - accuracy: 0.9820WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   60/1875 [..............................] - ETA: 1:40 - loss: 0.0648 - accuracy: 0.9823WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   61/1875 [..............................] - ETA: 1:40 - loss: 0.0639 - accuracy: 0.9826WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   62/1875 [..............................] - ETA: 1:40 - loss: 0.0643 - accuracy: 0.9824WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   63/1875 [>.............................] - ETA: 1:40 - loss: 0.0634 - accuracy: 0.9826WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   64/1875 [>.............................] - ETA: 1:39 - loss: 0.0625 - accuracy: 0.9829WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   65/1875 [>.............................] - ETA: 1:39 - loss: 0.0616 - accuracy: 0.9832WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   66/1875 [>.............................] - ETA: 1:39 - loss: 0.0608 - accuracy: 0.9834WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   67/1875 [>.............................] - ETA: 1:39 - loss: 0.0601 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   68/1875 [>.............................] - ETA: 1:40 - loss: 0.0593 - accuracy: 0.9839WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   69/1875 [>.............................] - ETA: 1:40 - loss: 0.0585 - accuracy: 0.9841WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   70/1875 [>.............................] - ETA: 1:39 - loss: 0.0577 - accuracy: 0.9844WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   71/1875 [>.............................] - ETA: 1:40 - loss: 0.0569 - accuracy: 0.9846WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   72/1875 [>.............................] - ETA: 1:40 - loss: 0.0647 - accuracy: 0.9835WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   73/1875 [>.............................] - ETA: 1:40 - loss: 0.0642 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   74/1875 [>.............................] - ETA: 1:40 - loss: 0.0636 - accuracy: 0.9840WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   75/1875 [>.............................] - ETA: 1:40 - loss: 0.0636 - accuracy: 0.9837WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   76/1875 [>.............................] - ETA: 1:40 - loss: 0.0647 - accuracy: 0.9836WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   77/1875 [>.............................] - ETA: 1:40 - loss: 0.0643 - accuracy: 0.9838WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   78/1875 [>.............................] - ETA: 1:40 - loss: 0.0655 - accuracy: 0.9836WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   79/1875 [>.............................] - ETA: 1:39 - loss: 0.0660 - accuracy: 0.9834WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   80/1875 [>.............................] - ETA: 1:39 - loss: 0.0663 - accuracy: 0.9828WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   81/1875 [>.............................] - ETA: 1:39 - loss: 0.0660 - accuracy: 0.9826WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   82/1875 [>.............................] - ETA: 1:39 - loss: 0.0655 - accuracy: 0.9829WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   83/1875 [>.............................] - ETA: 1:39 - loss: 0.0666 - accuracy: 0.9827WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   84/1875 [>.............................] - ETA: 1:39 - loss: 0.0669 - accuracy: 0.9825WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   85/1875 [>.............................] - ETA: 1:39 - loss: 0.0685 - accuracy: 0.9820WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   86/1875 [>.............................] - ETA: 1:39 - loss: 0.0692 - accuracy: 0.9815WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   87/1875 [>.............................] - ETA: 1:39 - loss: 0.0691 - accuracy: 0.9813WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   88/1875 [>.............................] - ETA: 1:39 - loss: 0.0690 - accuracy: 0.9812WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   89/1875 [>.............................] - ETA: 1:39 - loss: 0.0714 - accuracy: 0.9807WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   90/1875 [>.............................] - ETA: 1:39 - loss: 0.0708 - accuracy: 0.9809WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   91/1875 [>.............................] - ETA: 1:39 - loss: 0.0705 - accuracy: 0.9811WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   92/1875 [>.............................] - ETA: 1:39 - loss: 0.0702 - accuracy: 0.9810WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   93/1875 [>.............................] - ETA: 1:39 - loss: 0.0719 - accuracy: 0.9808WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   94/1875 [>.............................] - ETA: 1:39 - loss: 0.0711 - accuracy: 0.9811WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   95/1875 [>.............................] - ETA: 1:39 - loss: 0.0708 - accuracy: 0.9809WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   96/1875 [>.............................] - ETA: 1:39 - loss: 0.0716 - accuracy: 0.9805WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   97/1875 [>.............................] - ETA: 1:39 - loss: 0.0719 - accuracy: 0.9803WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   98/1875 [>.............................] - ETA: 1:39 - loss: 0.0720 - accuracy: 0.9799WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#   99/1875 [>.............................] - ETA: 1:39 - loss: 0.0734 - accuracy: 0.9789WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  100/1875 [>.............................] - ETA: 1:39 - loss: 0.0727 - accuracy: 0.9791WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  101/1875 [>.............................] - ETA: 1:39 - loss: 0.0720 - accuracy: 0.9793WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  102/1875 [>.............................] - ETA: 1:39 - loss: 0.0713 - accuracy: 0.9795WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  103/1875 [>.............................] - ETA: 1:39 - loss: 0.0721 - accuracy: 0.9794WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  104/1875 [>.............................] - ETA: 1:39 - loss: 0.0715 - accuracy: 0.9796WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  105/1875 [>.............................] - ETA: 1:39 - loss: 0.0713 - accuracy: 0.9795WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
#  106/1875 [>.............................] - ETA: 1:39 - loss: 0.0707 - accuracy: 0.9797WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ...
# 1157/1875 [=================>............] - ETA: 48s - loss: 0.0573 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1158/1875 [=================>............] - ETA: 48s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1159/1875 [=================>............] - ETA: 47s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1160/1875 [=================>............] - ETA: 47s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1161/1875 [=================>............] - ETA: 47s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1162/1875 [=================>............] - ETA: 47s - loss: 0.0573 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1163/1875 [=================>............] - ETA: 47s - loss: 0.0573 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1164/1875 [=================>............] - ETA: 47s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1165/1875 [=================>............] - ETA: 47s - loss: 0.0574 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1166/1875 [=================>............] - ETA: 47s - loss: 0.0573 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1167/1875 [=================>............] - ETA: 47s - loss: 0.0573 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1168/1875 [=================>............] - ETA: 47s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1169/1875 [=================>............] - ETA: 47s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1170/1875 [=================>............] - ETA: 47s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1171/1875 [=================>............] - ETA: 47s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1172/1875 [=================>............] - ETA: 47s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1173/1875 [=================>............] - ETA: 46s - loss: 0.0572 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1174/1875 [=================>............] - ETA: 46s - loss: 0.0571 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1175/1875 [=================>............] - ETA: 46s - loss: 0.0571 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1176/1875 [=================>............] - ETA: 46s - loss: 0.0570 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1177/1875 [=================>............] - ETA: 46s - loss: 0.0571 - accuracy: 0.9848WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1178/1875 [=================>............] - ETA: 46s - loss: 0.0570 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1179/1875 [=================>............] - ETA: 46s - loss: 0.0570 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1180/1875 [=================>............] - ETA: 46s - loss: 0.0570 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1181/1875 [=================>............] - ETA: 46s - loss: 0.0569 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1182/1875 [=================>............] - ETA: 46s - loss: 0.0569 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1183/1875 [=================>............] - ETA: 46s - loss: 0.0568 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1184/1875 [=================>............] - ETA: 46s - loss: 0.0568 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1185/1875 [=================>............] - ETA: 46s - loss: 0.0568 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1186/1875 [=================>............] - ETA: 46s - loss: 0.0567 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1187/1875 [=================>............] - ETA: 46s - loss: 0.0567 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1188/1875 [==================>...........] - ETA: 45s - loss: 0.0566 - accuracy: 0.9850WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1189/1875 [==================>...........] - ETA: 45s - loss: 0.0566 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1190/1875 [==================>...........] - ETA: 45s - loss: 0.0567 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1191/1875 [==================>...........] - ETA: 45s - loss: 0.0566 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1192/1875 [==================>...........] - ETA: 45s - loss: 0.0566 - accuracy: 0.9849WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net/batch_normalization_3/gamma:0', 'custom_res_net/batch_normalization_3/beta:0', 'custom_res_net/batch_normalization_6/gamma:0', 'custom_res_net/batch_normalization_6/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 1193/1875 [==================>...........] - ETA: 45s - loss: 0.0566 - accuracy: 0.9849

# %%
#evaluate model here
model.evaluate(x_test, y_test, batch_size=32)
# Out:
#   4/313 [..............................] - ETA: 6s - loss: 0.0195 - accuracy: 0.9922
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4527: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 313/313 [==============================] - 7s 21ms/step - loss: 0.0469 - accuracy: 0.9857
# [0.046937648206949234, 0.9857000112533569]

# %% [markdown]
# ## Congratulations!
# #### Now you know how to build class based models and custom layers!
